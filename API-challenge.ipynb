# %% [markdown]
# # WEATHER HOMEWORK

# %%
# install gmaps, citipy and api using pip install function

# Import dependencies
import gmaps
import citipy
import api
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# %%
#Read data
data=pd.read_csv('data_cities.csv')
data
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
os.chdir("C:\\Users\\sakon\\Desktop\\MASTER CSU\\CWRU_BOOTCAMP\\1.Hmw\\API-challenge")

# %%
data=pd.read_csv("data_cities.csv")
data
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sakon\\Desktop\\MASTER CSU\\CWRU_BOOTCAMP\\1.Hmw\\API-challenge'

# %%
gmaps.configure(api_key="AIzaSyCesYfww3dIY2FmS835OUOyejyl2tS9SBM")

# %%
import datetime
import time
date=datetime.datetime.fromtimestamp(int(data['Date'][0])).strftime('%m/%d/%Y')

# %%
#temperature vs latitude
scatterplotsTL= data.plot(kind="scatter", x="Lat", y="Max Temp", c='DarkBlue')
plt.title("Latitude versus temperature ({})".format(date))
plt.ylabel("Max Temperature (F)")
plt.grid()

# %%
# This scatter plot function is showing the latitude versus the temperature. The scatter plot has a circular 
# shape meaning that there is a quadratic relationship between the temperature.

# %%
# Humidity (%) vs. Latitude
scatterplotsHL=data.plot(kind="scatter", x="Lat", y="Humidity", c='DarkBlue')
plt.title("Humidity versus Latitude({})".format(date))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid()

# %%
# This scatter plot function is showing the latitude versus the humidity. The relationship is constant.

# %%
#Cloudiness (%) vs. Latitude
scatterplotsHL=data.plot(kind="scatter", x="Lat", y="Cloudiness", c='DarkBlue')
plt.title("Cloudiness versus Latitude({})".format(date))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid()

# %%
# This scatter plot function is showing the latitude versus the cloudness. The two variable has no trend

# %%
#Wind Speed (mph) vs. Latitude
scatterplotsHL=data.plot(kind="scatter", x="Lat", y="Wind Speed", c='DarkBlue')
plt.title("Cloudiness versus Latitude({})".format(date))
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid()

# %%
northernH_df=data.loc[(data["Lat"]>=0),:]
northernH_df
# Out:
#      City_ID               City  Cloudiness Country        Date  Humidity  \
# 0          0          ostrovnoy           2      RU  1558378754        72
# 2          2            qaanaaq          25      GL  1558378755        73
# 3          3             zhuhai           0      CN  1558378755        39
# 8          8              tiksi          95      RU  1558378756        88
# 9          9  pushkinskiye gory           6      RU  1558378756        70
# ..       ...                ...         ...     ...         ...       ...
# 543      543             yabrud           0      SY  1558378840        32
# 544      544            paraiso           5      MX  1558378898         4
# 545      545            veraval           0      FR  1558378898        62
# 546      546        novyy urgal         100      RU  1558378899        93
# 547      547            tongren           4      CN  1558378899        64
#
#        Lat     Lng  Max Temp  Wind Speed
# ...

# %%
southern_df=data.loc[(data["Lat"]<0),:]
southern_df
# Out:
#      City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 1          1  mahebourg          75      MU  1558378503        74 -20.41
# 4          4  cape town          20      ZA  1558378755        76 -33.93
# 5          5     atuona          78      PF  1558378755        76  -9.80
# 6          6   flinders           0      AU  1558378755        62 -34.58
# 7          7      opuwo           0     NaN  1558378523        23 -18.06
# ..       ...        ...         ...     ...         ...       ...    ...
# 526      526     viedma          14      AR  1558378894        41 -40.81
# 531      531    russell          75      AR  1558378895        71 -33.01
# 536      536     padang         100      ID  1558378896        82  -0.92
# 539      539       palu          72      ID  1558378897        80  -0.90
# 541      541   tamworth          64      AU  1558378897        87 -31.09
#
#         Lng  Max Temp  Wind Speed
# 1     57.70     78.80       11.41
# ...

# %%
from scipy.stats import linregress
from scipy import stats

# %%
x=northernH_df['Lat']
y=northernH_df['Max Temp']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=-0.8204052530215327, intercept=95.10898892434297, rvalue=-0.8151657406810829, pvalue=1.143275904489075e-91, stderr=0.029983753046137495)

# %%
a= -0.8204052530215327
b= 95.10898892434297 
y=northernH_df['Lat']*a+b
plt.scatter(northernH_df['Lat'], northernH_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Maximum temperature)')
plt.plot(northernH_df['Lat'], y, color='red')
plt.title('Temperature vs latitude in Northern hemisphere')
plt.show()

# %%
# The scatter plot shows a negative linear relationship between temperature and latitude.

# %%
x=northernH_df['Lat']
y=northernH_df['Humidity']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=0.11223395090861249, intercept=60.84793097541429, rvalue=0.10358336015746496, pvalue=0.04359225630131383, stderr=0.05543012819542627)

# %%
a= 0.11223395090861249
b= 60.84793097541429 
y=northernH_df['Lat']*a+b
plt.scatter(northernH_df['Lat'], northernH_df['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.plot(northernH_df['Lat'], y, color='red')
plt.title('Humidity vs latitude in Northern hemisphere')
plt.show()

# %%
# The scatter plot shows no relationship between humidity and latitude.

# %%
x=northernH_df['Lat']
y=northernH_df['Cloudiness']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=-0.1549687937388599, intercept=55.93576697284077, rvalue=-0.08733547918934018, pvalue=0.08910778853888567, stderr=0.09091698154938403)

# %%
a= -0.1549687937388599
b= 55.93576697284077
y=northernH_df['Lat']*a+b
plt.scatter(northernH_df['Lat'], northernH_df['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness)')
plt.plot(northernH_df['Lat'], y, color='red')
plt.title('Cloudiness vs latitude in Northern hemisphere')
plt.show()

# %%
# The scatter plot shows no relationship between cloudiness and latitude.

# %%
x=northernH_df['Lat']
y=northernH_df['Wind Speed']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=0.029016896110896962, intercept=7.7893504133859075, rvalue=0.10713827743884798, pvalue=0.03683020311076798, stderr=0.013850116639559972)

# %%
a=0.029016896110896962
b= 7.7893504133859075
y=northernH_df['Lat']*a+b
plt.scatter(northernH_df['Lat'], northernH_df['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.plot(northernH_df['Lat'], y, color='red')
plt.title('Wind Speed vs latitude in Northern hemisphere')
plt.show()

# %%
# The scatter plot shows no linear relationship between wind speed and latitude.

# %%
x=southern_df['Lat']
y=southern_df['Max Temp']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=0.6831901314636507, intercept=82.7832526896806, rvalue=0.7602633550516462, pvalue=6.446177216249583e-33, stderr=0.04530848264502712)

# %%
a= 0.6831901314636507
b= 82.7832526896806
y=southern_df['Lat']*a+b
plt.scatter(southern_df['Lat'], southern_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Maximum temperature)')
plt.plot(southern_df['Lat'], y, color='red')
plt.title('Temperature vs latitude in Southern hemisphere')
plt.show()

# %%
# The scatter plot shows positive linear relationship between temperature and latitude in the Southern hemisphere.

# %%
x=southern_df['Lat']
y=southern_df['Humidity']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=0.26631531961419325, intercept=79.32476106759104, rvalue=0.14689473425583074, pvalue=0.05742280964524563, stderr=0.13918709428099224)

# %%
a= 0.26631531961419325
b= 79.32476106759104
y=southern_df['Lat']*a+b
plt.scatter(southern_df['Lat'], southern_df['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.plot(southern_df['Lat'], y, color='red')
plt.title('Humidity vs latitude in Southern hemisphere')
plt.show()

# %%
# The scatter plot shows no linear relationship between humidity and latitude in the Southern hemisphere.

# %%
x=southern_df['Lat']
y=southern_df['Cloudiness']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=0.5835538986271136, intercept=60.95780485548951, rvalue=0.21881426893991604, pvalue=0.004377453956962988, stderr=0.2019748097666344)

# %%
a= 0.5835538986271136
b= 60.95780485548951
y=southern_df['Lat']*a+b
plt.scatter(southern_df['Lat'], southern_df['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.plot(southern_df['Lat'], y, color='red')
plt.title('Cloudiness vs latitude in Southern hemisphere')
plt.show()

# %%
# The scatter plot shows no linear relationship between Cloudiness and latitude in Southern hemisphere.

# %%
x=southern_df['Lat']
y=southern_df['Wind Speed']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
linregress(x,y)
# Out:
# LinregressResult(slope=-0.14683925784406715, intercept=4.908087009658233, rvalue=-0.3224830771395381, pvalue=2.0160363918768926e-05, stderr=0.03345309801467268)

# %%
a= -0.14683925784406715
b= 4.908087009658233
y=southern_df['Lat']*a+b
plt.scatter(southern_df['Lat'], southern_df['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.plot(southern_df['Lat'], y, color='red')
plt.title('Wind Speed vs latitude in Southern hemisphere')
plt.show()

# %%
# The scatter plot shows a negative linear relationship between wind speed and latitude in the Southern hemisphere.

# %% [markdown]
# # VACATION HOMEWORK

# %%
# Create a heat map that displays the humidity for every city from the weather data
gmaps.configure(api_key="AIzaSyAqMXyVZE9klNfF2x9X_l1o1lKKkKWFUgQ")

# %%
g_key= 'AIzaSyAqMXyVZE9klNfF2x9X_l1o1lKKkKWFUgQ'
gmaps.configure(api_key=g_key)

# %%
gmaps.configure(api_key=g_key)

# %%
figure_layout={"width":"450px", 
               "height":"450px", 
               "border":"3px", 
               "padding":"3px"
              }
gmaps.figure(layout=figure_layout)
# Out:
# Figure(layout=FigureLayout(border='3px', height='450px', padding='3px', width='450px'))

# %%
locations=data[["Lat", "Lng"]]
weight=data["Humidity"]
fig=gmaps.figure(layout=figure_layout, map_type="HYBRID")
heatmap_layer=gmaps.heatmap_layer(locations, weights=weight)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='3px', height='350px', padding='3px', width='350px'))

# %%
# Narrow down the DataFrame to find your ideal weather condition
Datavac= data.loc[(data["Max Temp"]>70)& (data["Max Temp"]<80)& (data["Cloudiness"]==0) & (data["Wind Speed"]<10), :]
Datavac=Datavac.dropna(how="any")
Datavac.reset_index(inplace=True)
del Datavac["index"]
Datavac
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0       70  ponta do sol           0      BR  1558378767        57 -20.63
# 1       88      cidreira           0      BR  1558378770        66 -30.17
# 2      138     morondava           0      MG  1558378780        69 -20.30
# 3      139         vaini           0      IN  1558378780        88  15.34
# 4      176         nador           0      MA  1558378499        40  35.17
# 5      297         mogok           0      MM  1558378844        51  22.92
# 6      444       birjand           0      IR  1558378880        26  32.86
#
#      Lng  Max Temp  Wind Speed
# 0 -46.00     73.68        5.32
# 1 -50.22     76.56        5.50
# 2  44.28     79.08        9.06
# 3  74.49     78.90        1.59
# 4  -2.93     75.20        6.93
# 5  96.51     72.24        2.77
# 6  59.22     71.60        9.17

# %%
# Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates
hotel=[]
g_key=""
for i in range(len(Datavac)):
    lat=Datavac.loc[i]["Lat"]
    long=Datavac.loc[i]["Lng"]
    
    params={
        "location": f"{lat},{long}",
        "radius": 5000,
        "types" : "hotel",
        "key": g_key
    }
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    requested = requests.get(base_url, params=params)
    jsn = requested.json()
    try:
        hotel.append(jsn['results'][0]['name'])
    except:
        hotel.append("")
Datavac["Hotel Name"]=hotel
Datavac= Datavac.dropna(how='any')
Datavac.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0       70  ponta do sol           0      BR  1558378767        57 -20.63
# 1       88      cidreira           0      BR  1558378770        66 -30.17
# 2      138     morondava           0      MG  1558378780        69 -20.30
# 3      139         vaini           0      IN  1558378780        88  15.34
# 4      176         nador           0      MA  1558378499        40  35.17
#
#      Lng  Max Temp  Wind Speed Hotel Name
# 0 -46.00     73.68        5.32
# 1 -50.22     76.56        5.50
# 2  44.28     79.08        9.06
# 3  74.49     78.90        1.59
# 4  -2.93     75.20        6.93

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in Datavac.iterrows()]
locations = Datavac[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
# Display figure
markers = gmaps.marker_layer(locations, hover_text='',
    label='', info_box_content=None, display_info_box=None,)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='3px', height='350px', padding='3px', width='350px'))

# %%
#import dependencies
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import gmaps
from pprint import pprint
import datetime

# %%
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
api_key='3a9fa2731241e7ab03bbf05564b12ba4'

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a9fa2731241e7ab03bbf05564b12ba4
# Processing record 2 of set 0 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a9fa2731241e7ab03bbf05564b12ba4
# Processing record 3 of set 0 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a9fa2731241e7ab03bbf05564b12ba4
# Processing record 4 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a9fa2731241e7ab03bbf05564b12ba4
# Processing record 5 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a9fa2731241e7ab03bbf05564b12ba4
# Processing record 6 of set 0 | talawdi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a9fa2731241e7ab03bbf05564b12ba4
# City not found!
# ...

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          568
# Cloudiness    568
# Country       568
# Date          568
# Humidity      568
# Temp          568
# Lat           568
# Lng           568
# Wind Speed    568
# dtype: int64

# %%
weather_data
# Out:
#               City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0          iqaluit          90      CA  1592452579        90  37.40  63.75
# 1           faanui          98      PF  1592452579        74  81.70 -16.48
# 2         meulaboh          93      ID  1592452579        62  84.79   4.14
# 3        cape town           0      ZA  1592452579        75  50.00 -33.93
# 4        busselton          29      AU  1592452526        55  60.01 -33.65
# ..             ...         ...     ...         ...       ...    ...    ...
# 563  alice springs           0      AU  1592452602        22  71.60 -23.70
# 564         sorong           0      ID  1592452630        67  86.45  -0.88
# 565        worland           1      US  1592452630        66  53.60  44.02
# 566          homer          90      US  1592452630        76  55.00  59.64
# 567  prince rupert          90      CA  1592452495        87  57.20  54.32
#
#         Lng  Wind Speed
# 0    -68.51        8.05
# ...

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('..', 'API-challenge', 'cities.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)
